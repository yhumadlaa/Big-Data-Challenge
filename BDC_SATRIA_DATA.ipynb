# %% [markdown]
# <a href="https://colab.research.google.com/github/yhumadlaa/Big-Data-Challenge/blob/main/BDC_SATRIA_DATA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
read_file = pd.read_csv (r'/content/gdrive/My Drive/BDC/train_fktp.txt',
                         names = ['PSTV01','PSTV02','PSTV15','FKP02','FKP03','FKP04','FKP05','FKP06','FKP07',
                                 'FKP08','FKP09','FKP10','FKP11','FKP12','FKP14','FKP14A','FKP15','FKP15A',
                                 'FKP16','FKP17','FKP18','FKP19','FKP20','FKP21','FKP22','FKP13Class'])
read_file.to_csv (r'/content/gdrive/My Drive/BDC/train_fktp.csv', index=None)

# %%
read_file
# Out:
#               PSTV01     PSTV02      PSTV15             FKP02       FKP03  \
# 0        157978748.0   50765420   20.064983         958073632  2019-08-01
# 1         95085112.0   26931775    2.626307  449590620P000054  2020-06-17
# 2        224470578.0  227368233    1.051830  467490619P000001  2019-06-01
# 3         63871289.0   62313678  364.741455  254321219Y002368  2019-12-21
# 4         29915626.0  113446188    1.050523   88681119P000020  2019-11-04
# ...              ...        ...         ...               ...         ...
# 4056893  212666736.0   91270403   14.246229        1285820875  2020-07-29
# 4056894   30859241.0   30859241    3.886934  315641120P000514  2020-11-14
# 4056895    8859416.0    8859416    6.146070         962412926  2019-08-16
# 4056896  399491834.0  399491834   26.548826  273170420P000003  2020-04-01
# 4056897   99146724.0   39321920   88.348953        1188955927  2020-03-14
#
#               FKP04  FKP05  FKP06  FKP07  FKP08  ...  FKP15  \
# ...

# %%
import pandas as pd
df = pd.DataFrame(read_file)
#df.isna().sum()
df.drop('FKP14A', axis=1, inplace=True)
modus = df['FKP11'].mode()[0]
df['FKP11'] = df['FKP11'].fillna(modus)
df.isna().sum()
# Out:
# PSTV01        0
# PSTV02        0
# PSTV15        0
# FKP02         0
# FKP03         0
# FKP04         0
# FKP05         0
# FKP06         0
# FKP07         0
# FKP08         0
# FKP09         0
# FKP10         0
# FKP11         0
# FKP12         0
# FKP14         0
# FKP15         0
# FKP15A        0
# FKP16         0
# FKP17         0
# FKP18         0
# FKP19         0
# FKP20         0
# FKP21         0
# FKP22         0
# FKP13Class    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4056898 entries, 0 to 4056897
# Data columns (total 25 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   PSTV01      float64
#  1   PSTV02      int64
#  2   PSTV15      float64
#  3   FKP02       object
#  4   FKP03       object
#  5   FKP04       object
#  6   FKP05       int64
#  7   FKP06       int64
#  8   FKP07       int64
#  9   FKP08       int64
#  10  FKP09       int64
#  11  FKP10       int64
#  12  FKP11       float64
#  13  FKP12       int64
#  14  FKP14       int64
#  15  FKP15       object
#  16  FKP15A      object
#  17  FKP16       int64
#  18  FKP17       int64
#  19  FKP18       int64
#  20  FKP19       int64
#  21  FKP20       int64
#  22  FKP21       int64
#  23  FKP22       int64
#  24  FKP13Class  object
# dtypes: float64(3), int64(16), object(6)
# memory usage: 773.8+ MB

# %%
df.duplicated().any()
# Out:
# False

# %%
df
# Out:
#               PSTV01     PSTV02      PSTV15             FKP02       FKP03  \
# 0        157978748.0   50765420   20.064983         958073632  2019-08-01
# 1         95085112.0   26931775    2.626307  449590620P000054  2020-06-17
# 2        224470578.0  227368233    1.051830  467490619P000001  2019-06-01
# 3         63871289.0   62313678  364.741455  254321219Y002368  2019-12-21
# 4         29915626.0  113446188    1.050523   88681119P000020  2019-11-04
# ...              ...        ...         ...               ...         ...
# 4056893  212666736.0   91270403   14.246229        1285820875  2020-07-29
# 4056894   30859241.0   30859241    3.886934  315641120P000514  2020-11-14
# 4056895    8859416.0    8859416    6.146070         962412926  2019-08-16
# 4056896  399491834.0  399491834   26.548826  273170420P000003  2020-04-01
# 4056897   99146724.0   39321920   88.348953        1188955927  2020-03-14
#
#               FKP04  FKP05  FKP06  FKP07  FKP08  ...  FKP15  \
# ...

# %%
df.describe()
# Out:
#              PSTV01        PSTV02        PSTV15         FKP05         FKP06  \
# count  4.056898e+06  4.056898e+06  4.056898e+06  4.056898e+06  4.056898e+06
# mean   9.153457e+07  9.488335e+07  1.056512e+02  3.608867e+01  3.636691e+03
# std    8.994426e+07  8.852257e+07  1.886474e+02  1.870093e+01  1.869268e+03
# min    1.500000e+01  1.500000e+01  5.106980e-01  1.100000e+01  1.101000e+03
# 25%    3.377226e+07  3.577565e+07  1.676808e+01  3.100000e+01  3.171000e+03
# 50%    6.760764e+07  7.181594e+07  5.147561e+01  3.300000e+01  3.318000e+03
# 75%    1.015584e+08  1.113200e+08  1.282688e+02  3.600000e+01  3.603000e+03
# max    4.553885e+08  4.553824e+08  3.035342e+04  9.400000e+01  9.471000e+03
#
#               FKP07         FKP08         FKP09         FKP10         FKP11  \
# count  4.056898e+06  4.056898e+06  4.056898e+06  4.056898e+06  4.056898e+06
# mean   5.652855e+00  1.677882e+00  2.709430e+00  1.064594e+00  5.239781e+00
# ...

# %%
import numpy as np
q1,q3 = np.percentile(df['PSTV01'],[25,75])
print(q1)
print(q3)
# Out:
# 33772260.0
# 101558416.0

# %%
iqr=q3-q1
iqr
# Out:
# 67786156.0

# %%
ba=q3+(1.5*iqr)
bb=q1-(1.5*iqr)
print(ba)
print(bb)
# Out:
# 203237650.0
# -67906974.0

# %%
out_pstv01=df[(df['PSTV01']>bb) & (df['PSTV01']<ba)]
out_pstv01
# Out:
#               PSTV01     PSTV02      PSTV15             FKP02       FKP03  \
# 0        157978748.0   50765420   20.064983         958073632  2019-08-01
# 1         95085112.0   26931775    2.626307  449590620P000054  2020-06-17
# 3         63871289.0   62313678  364.741455  254321219Y002368  2019-12-21
# 4         29915626.0  113446188    1.050523   88681119P000020  2019-11-04
# 5        189355720.0   69855169   30.044949   97010720P000238  2020-07-15
# ...              ...        ...         ...               ...         ...
# 4056891   40295955.0   40295955  162.410797  257350819Y001095  2019-08-04
# 4056892   49303763.0   49303763  581.884521         989864751  2019-09-23
# 4056894   30859241.0   30859241    3.886934  315641120P000514  2020-11-14
# 4056895    8859416.0    8859416    6.146070         962412926  2019-08-16
# 4056897   99146724.0   39321920   88.348953        1188955927  2020-03-14
#
#               FKP04  FKP05  FKP06  FKP07  FKP08  ...  FKP15  \
# ...

# %%
out_pstv01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3574768 entries, 0 to 4056897
# Data columns (total 25 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   PSTV01      float64
#  1   PSTV02      int64
#  2   PSTV15      float64
#  3   FKP02       object
#  4   FKP03       object
#  5   FKP04       object
#  6   FKP05       int64
#  7   FKP06       int64
#  8   FKP07       int64
#  9   FKP08       int64
#  10  FKP09       int64
#  11  FKP10       int64
#  12  FKP11       float64
#  13  FKP12       int64
#  14  FKP14       int64
#  15  FKP15       object
#  16  FKP15A      object
#  17  FKP16       int64
#  18  FKP17       int64
#  19  FKP18       int64
#  20  FKP19       int64
#  21  FKP20       int64
#  22  FKP21       int64
#  23  FKP22       int64
#  24  FKP13Class  object
# dtypes: float64(3), int64(16), object(6)
# memory usage: 709.1+ MB

# %%
q1,q3 = np.percentile(df['PSTV02'],[25,75])
print(q1)
print(q3)

# %%
iqr=q3-q1
iqr

# %%
ba=q3+(1.5*iqr)
bb=q1-(1.5*iqr)
print(ba)
print(bb)

# %%
out_pstv02=df[(df['PSTV02']>bb) & (df['PSTV02']<ba)]
out_pstv02.info()

# %%
q1,q3 = np.percentile(df['PSTV15'],[25,75])
print(q1)
print(q3)

# %%
iqr=q3-q1
iqr

# %%
ba=q3+(1.5*iqr)
bb=q1-(1.5*iqr)
print(ba)
print(bb)

# %%
out_pstv15=df[(df['PSTV15']>bb) & (df['PSTV15']<ba)]
out_pstv15.info()

# %%
q1,q3 = np.percentile(df['FKP05'],[25,75])
print(q1)
print(q3)

# %%
iqr=q3-q1
iqr

# %%
ba=q3+(1.5*iqr)
bb=q1-(1.5*iqr)
print(ba)
print(bb)

# %%
out_fkp05=df[(df['FKP05']>bb) & (df['FKP05']<ba)]
out_fkp05.info()

# %%
q1,q3 = np.percentile(df['FKP06'],[25,75])
iqr=q3-q1
ba=q3+(1.5*iqr)
bb=q1-(1.5*iqr)
out_fkp06=df[(df['FKP06']>bb) & (df['FKP06']<ba)]
out_fkp06.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2126203 entries, 2 to 4056894
# Data columns (total 25 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   PSTV01      float64
#  1   PSTV02      int64
#  2   PSTV15      float64
#  3   FKP02       object
#  4   FKP03       object
#  5   FKP04       object
#  6   FKP05       int64
#  7   FKP06       int64
#  8   FKP07       int64
#  9   FKP08       int64
#  10  FKP09       int64
#  11  FKP10       int64
#  12  FKP11       float64
#  13  FKP12       int64
#  14  FKP14       int64
#  15  FKP15       object
#  16  FKP15A      object
#  17  FKP16       int64
#  18  FKP17       int64
#  19  FKP18       int64
#  20  FKP19       int64
#  21  FKP20       int64
#  22  FKP21       int64
#  23  FKP22       int64
#  24  FKP13Class  object
# dtypes: float64(3), int64(16), object(6)
# memory usage: 421.8+ MB

# %%
q1,q3 = np.percentile(df['FKP07'],[25,75])
print(q1)
print(q3)
iqr=q3-q1
print(iqr)
ba=q3+(1.5*iqr)
bb=q1-(1.5*iqr)
print(ba)
print(bb)
out_fkp07=df[(df['FKP07']>bb) & (df['FKP07']<ba)]
out_fkp07.info()

# %%
q1,q3 = np.percentile(df['FKP08'],[25,75])
iqr=q3-q1
ba=q3+(1.5*iqr)
bb=q1-(1.5*iqr)
out_fkp08=df[(df['FKP08']>bb) & (df['FKP08']<ba)]
out_fkp08.info()

# %%
q1,q3 = np.percentile(df['FKP09'],[25,75])
iqr=q3-q1
ba=q3+(1.5*iqr)
bb=q1-(1.5*iqr)
out_fkp09=df[(df['FKP09']>bb) & (df['FKP09']<ba)]
out_fkp09.info()

# %%
q1,q3 = np.percentile(df['FKP10'],[25,75])
print(q1)
print(q3)
iqr=q3-q1
print(iqr)
ba=q3+(1.5*iqr)
bb=q1-(1.5*iqr)
print(ba)
print(bb)
out_fkp10=df[(df['FKP10']>bb) & (df['FKP10']<ba)]
out_fkp10.info()

# %%
q1,q3 = np.percentile(df['FKP11'],[25,75])
iqr=q3-q1
ba=q3+(1.5*iqr)
bb=q1-(1.5*iqr)
out_fkp11=df[(df['FKP11']>bb) & (df['FKP11']<ba)]
out_fkp11.info()

# %%
q1,q3 = np.percentile(df['FKP12'],[25,75])
iqr=q3-q1
ba=q3+(1.5*iqr)
bb=q1-(1.5*iqr)
out_fkp12=df[(df['FKP12']>bb) & (df['FKP12']<ba)]
out_fkp12.info()

# %%
q1,q3 = np.percentile(df['FKP14'],[25,75])
iqr=q3-q1
ba=q3+(1.5*iqr)
bb=q1-(1.5*iqr)
out_fkp14=df[(df['FKP14']>bb) & (df['FKP14']<ba)]
out_fkp14.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4056898 entries, 0 to 4056897
# Data columns (total 25 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   PSTV01      float64
#  1   PSTV02      int64
#  2   PSTV15      float64
#  3   FKP02       object
#  4   FKP03       object
#  5   FKP04       object
#  6   FKP05       int64
#  7   FKP06       int64
#  8   FKP07       int64
#  9   FKP08       int64
#  10  FKP09       int64
#  11  FKP10       int64
#  12  FKP11       float64
#  13  FKP12       int64
#  14  FKP14       int64
#  15  FKP15       object
#  16  FKP15A      object
#  17  FKP16       int64
#  18  FKP17       int64
#  19  FKP18       int64
#  20  FKP19       int64
#  21  FKP20       int64
#  22  FKP21       int64
#  23  FKP22       int64
#  24  FKP13Class  int64
# dtypes: float64(3), int64(17), object(5)
# memory usage: 804.7+ MB

# %%
q1,q3 = np.percentile(df['FKP16'],[25,75])
iqr=q3-q1
ba=q3+(1.5*iqr)
bb=q1-(1.5*iqr)
out_fkp16=df[(df['FKP16']>bb) & (df['FKP16']<ba)]
out_fkp16.info()

# %%
q1,q3 = np.percentile(df['FKP17'],[25,75])
iqr=q3-q1
ba=q3+(1.5*iqr)
bb=q1-(1.5*iqr)
out_fkp17=df[(df['FKP17']>bb) & (df['FKP17']<ba)]
out_fkp17.info()

# %%
q1,q3 = np.percentile(df['FKP18'],[25,75])
iqr=q3-q1
ba=q3+(1.5*iqr)
bb=q1-(1.5*iqr)
out_fkp18=df[(df['FKP18']>bb) & (df['FKP18']<ba)]
out_fkp18.info()

# %%
q1,q3 = np.percentile(df['FKP19'],[25,75])
iqr=q3-q1
ba=q3+(1.5*iqr)
bb=q1-(1.5*iqr)
out_fkp19=df[(df['FKP19']>bb) & (df['FKP19']<ba)]
out_fkp19.info()

# %%
q1,q3 = np.percentile(df['FKP20'],[25,75])
iqr=q3-q1
ba=q3+(1.5*iqr)
bb=q1-(1.5*iqr)
out_fkp20=df[(df['FKP20']>bb) & (df['FKP20']<ba)]
out_fkp20.info()

# %%
q1,q3 = np.percentile(df['FKP21'],[25,75])
iqr=q3-q1
ba=q3+(1.5*iqr)
bb=q1-(1.5*iqr)
out_fkp21=df[(df['FKP21']>bb) & (df['FKP21']<ba)]
out_fkp21.info()

# %%
q1,q3 = np.percentile(df['FKP22'],[25,75])
iqr=q3-q1
ba=q3+(1.5*iqr)
bb=q1-(1.5*iqr)
out_fkp22=df[(df['FKP22']>bb) & (df['FKP22']<ba)]
out_fkp22.info()

# %%
df

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
df['FKP13Class'] = encoder.fit_transform(df['FKP13Class'])

# %%
df
# Out:
#               PSTV01     PSTV02      PSTV15             FKP02       FKP03  \
# 0        157978748.0   50765420   20.064983         958073632  2019-08-01
# 1         95085112.0   26931775    2.626307  449590620P000054  2020-06-17
# 2        224470578.0  227368233    1.051830  467490619P000001  2019-06-01
# 3         63871289.0   62313678  364.741455  254321219Y002368  2019-12-21
# 4         29915626.0  113446188    1.050523   88681119P000020  2019-11-04
# ...              ...        ...         ...               ...         ...
# 4056893  212666736.0   91270403   14.246229        1285820875  2020-07-29
# 4056894   30859241.0   30859241    3.886934  315641120P000514  2020-11-14
# 4056895    8859416.0    8859416    6.146070         962412926  2019-08-16
# 4056896  399491834.0  399491834   26.548826  273170420P000003  2020-04-01
# 4056897   99146724.0   39321920   88.348953        1188955927  2020-03-14
#
#               FKP04  FKP05  FKP06  FKP07  FKP08  ...  FKP15  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4056898 entries, 0 to 4056897
# Data columns (total 25 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   PSTV01      float64
#  1   PSTV02      int64
#  2   PSTV15      float64
#  3   FKP02       object
#  4   FKP03       object
#  5   FKP04       object
#  6   FKP05       int64
#  7   FKP06       int64
#  8   FKP07       int64
#  9   FKP08       int64
#  10  FKP09       int64
#  11  FKP10       int64
#  12  FKP11       float64
#  13  FKP12       int64
#  14  FKP14       int64
#  15  FKP15       object
#  16  FKP15A      object
#  17  FKP16       int64
#  18  FKP17       int64
#  19  FKP18       int64
#  20  FKP19       int64
#  21  FKP20       int64
#  22  FKP21       int64
#  23  FKP22       int64
#  24  FKP13Class  int64
# dtypes: float64(3), int64(17), object(5)
# memory usage: 773.8+ MB

# %%
import numpy as np
x = np.array(df['FKP22'] + df['FKP09'] + df['FKP05'] + df['FKP06'] + df['FKP07'] + df['FKP08'] + df['FKP10'] + df['FKP11'] + df['FKP12'] + df['FKP14']).reshape(-1,1)

# %%
x.shape
# Out:
# (4056898, 1)

# %%
y = np.array(df['FKP13Class'])

# %%
y.shape
# Out:
# (4056898,)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.25)

# %%
x_train.shape
# Out:
# (3042673, 1)

# %%
x_test.shape
# Out:
# (1014225, 1)

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

from sklearn.calibration import CalibratedClassifierCV, CalibrationDisplay
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB

lr = LogisticRegression(C=1.0)
gnb = GaussianNB()
gnb_isotonic = CalibratedClassifierCV(gnb, cv=2, method="isotonic")
gnb_sigmoid = CalibratedClassifierCV(gnb, cv=2, method="sigmoid")

clf_list = [
    (lr, "Logistic"),
    (gnb, "Naive Bayes"),
    (gnb_isotonic, "Naive Bayes + Isotonic"),
    (gnb_sigmoid, "Naive Bayes + Sigmoid"),
]

# %%
fig = plt.figure(figsize=(10, 10))
gs = GridSpec(4, 2)
colors = plt.cm.get_cmap("Dark2")

ax_calibration_curve = fig.add_subplot(gs[:2, :2])
calibration_displays = {}
for i, (clf, name) in enumerate(clf_list):
    clf.fit(x_train, y_train)
    display = CalibrationDisplay.from_estimator(
        clf,
        x_test,
        y_test,
        n_bins=10,
        name=name,
        ax=ax_calibration_curve,
        color=colors(i),
    )
    calibration_displays[name] = display

ax_calibration_curve.grid()
ax_calibration_curve.set_title("Calibration plots (Naive Bayes)")

# Add histogram
grid_positions = [(2, 0), (2, 1), (3, 0), (3, 1)]
for i, (_, name) in enumerate(clf_list):
    row, col = grid_positions[i]
    ax = fig.add_subplot(gs[row, col])

    ax.hist(
        calibration_displays[name].y_prob,
        range=(0, 1),
        bins=10,
        label=name,
        color=colors(i),
    )
    ax.set(title=name, xlabel="Mean predicted probability", ylabel="Count")

plt.tight_layout()
plt.show()

# %%
from collections import defaultdict

import pandas as pd

from sklearn.metrics import (
    precision_score,
    recall_score,
    f1_score,
    brier_score_loss,
    log_loss,
    roc_auc_score,
)

scores = defaultdict(list)
for i, (clf, name) in enumerate(clf_list):
    clf.fit(x_train, y_train)
    y_prob = clf.predict_proba(x_test)
    y_pred = clf.predict(x_test)
    scores["Classifier"].append(name)

    for metric in [brier_score_loss, log_loss]:
        score_name = metric.__name__.replace("_", " ").replace("score", "").capitalize()
        scores[score_name].append(metric(y_test, y_prob[:, 1]))

    for metric in [precision_score, recall_score, f1_score, roc_auc_score]:
        score_name = metric.__name__.replace("_", " ").replace("score", "").capitalize()
        scores[score_name].append(metric(y_test, y_pred))

    score_df = pd.DataFrame(scores).set_index("Classifier")
    score_df.round(decimals=3)

score_df
# Out:
#                         Brier  loss  Log loss  Precision    Recall        F1   \
# Classifier
# Logistic                   0.016494  0.094664    0.982811  0.971042  0.976891
# Naive Bayes                0.021198  0.114002    0.956643  0.971482  0.964005
# Naive Bayes + Isotonic     0.010450  0.054516    0.999050  0.970660  0.984650
# Naive Bayes + Sigmoid      0.019003  0.089701    0.965705  0.971356  0.968522
#
#                         Roc auc
# Classifier
# Logistic                0.980922
# Naive Bayes             0.973819
# Naive Bayes + Isotonic  0.985080
# Naive Bayes + Sigmoid   0.976337

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
read_file1 = pd.read_csv (r'/content/gdrive/My Drive/BDC/test_fktp.txt',
                         names = ['PSTV01','PSTV02','PSTV15','FKP02','FKP03','FKP04','FKP05','FKP06','FKP07',
                                 'FKP08','FKP09','FKP10','FKP11','FKP12','FKP14','FKP14A','FKP15','FKP15A',
                                 'FKP16','FKP17','FKP18','FKP19','FKP20','FKP21','FKP22','FKP13Class'])
read_file1.to_csv (r'/content/gdrive/My Drive/BDC/test_fktp.csv', index=None)
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (3,15,16,17) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
read_file1
# Out:
#               PSTV01     PSTV02      PSTV15             FKP02       FKP03  \
# 0        187883292.0   98048784  240.884842         954386050  2019-08-21
# 1        123307139.0   20969999   47.378571         774246805  2019-02-12
# 2         21416273.0   21416273    5.882927        1202010273  2020-03-27
# 3         97630052.0   97630052  172.916031        1286640248  2020-07-30
# 4        124531163.0  124531163  187.203140        1285179242  2020-07-28
# ...              ...        ...         ...               ...         ...
# 1014220   51801010.0   51801010    7.563763  248870919P000406  2019-09-08
# 1014221  339397889.0  339397889   11.063568  116000620P000034  2020-06-02
# 1014222   76213152.0   76213152  286.792694  160421019P000631  2019-10-15
# 1014223  101797983.0  101797983   30.222155  332670919P000083  2019-09-06
# 1014224   20239553.0   20239553  233.636230  106050119Y000587  2019-01-30
#
#               FKP04  FKP05  FKP06  FKP07  FKP08  ...  FKP15  \
# ...

# %%
import numpy as np
x_train = np.array(df['FKP22'] + df['FKP09'] + df['FKP05'] + df['FKP06'] + df['FKP07'] + df['FKP08'] + df['FKP10'] + df['FKP12'] + df['FKP14']).reshape(-1,1)

# %%
x_train.shape
# Out:
# (4056898, 1)

# %%
y_train = np.array(df['FKP13Class'])

# %%
y_train.shape
# Out:
# (4056898,)

# %%
import numpy as np
x_test = np.array(read_file1['FKP22'] + read_file1['FKP09'] + read_file1['FKP05'] + read_file1['FKP06'] + read_file1['FKP07'] + read_file1['FKP08'] + read_file1['FKP10'] + read_file1['FKP12'] + read_file1['FKP14']).reshape(-1,1)

# %%
x_test.shape
# Out:
# (1014225, 1)

# %%
y_test = np.array(read_file1['FKP13Class'])

# %%
y_test.shape
# Out:
# (1014225,)

# %%
from sklearn.calibration import CalibratedClassifierCV, CalibrationDisplay
from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB()
gnb_isotonic = CalibratedClassifierCV(gnb, cv=2, method="isotonic")
nbtrain = gnb_isotonic.fit(x_train, y_train)

# %%
# Menentukan hasil prediksi dari x_test
y_pred = nbtrain.predict(x_test)
print(y_pred[0:len(y_pred)])
# Out:
# [1 1 1 ... 0 0 0]

# %%
# Convert array into dataframe
y_pred = pd.DataFrame(y_pred, columns=['Status'])
y_pred
# Out:
#          Status
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ...         ...
# 1014220       0
# 1014221       0
# 1014222       0
# 1014223       0
# 1014224       0
#
# [1014225 rows x 1 columns]

# %%
# Menambahkan nama variabel saat read csv
data_output = pd.read_csv('/content/gdrive/My Drive/BDC/submission.csv')
data_output.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    Unnamed: 0       FKP02  Status
# 0           1   954386050     NaN
# 1           2   774246805     NaN
# 2           3  1202010273     NaN
# 3           4  1286640248     NaN
# 4           5  1285179242     NaN

# %%
data_output = data_output.drop('Status', axis = 1)
data_output['Status'] = y_pred['Status'] 
data_output.rename(columns = {'Unnamed: 0':''}, inplace = True)
data_output
# Out:
#                              FKP02  Status
# 0              1         954386050       1
# 1              2         774246805       1
# 2              3        1202010273       1
# 3              4        1286640248       1
# 4              5        1285179242       1
# ...          ...               ...     ...
# 1014220  1014221  248870919P000406       0
# 1014221  1014222  116000620P000034       0
# 1014222  1014223  160421019P000631       0
# 1014223  1014224  332670919P000083       0
# 1014224  1014225  106050119Y000587       0
#
# [1014225 rows x 3 columns]

# %%
data_to_string = data_output[['','FKP02']].astype('string')
data_to_string.head()
# Out:
#            FKP02
# 0  1   954386050
# 1  2   774246805
# 2  3  1202010273
# 3  4  1286640248
# 4  5  1285179242

# %%
data_num = data_output['Status'].astype('int')
data_num.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Status, dtype: int64

# %%
data_fix = pd.concat([data_to_string, data_num], axis = 1)
data_fix
# Out:
#                              FKP02  Status
# 0              1         954386050       1
# 1              2         774246805       1
# 2              3        1202010273       1
# 3              4        1286640248       1
# 4              5        1285179242       1
# ...          ...               ...     ...
# 1014220  1014221  248870919P000406       0
# 1014221  1014222  116000620P000034       0
# 1014222  1014223  160421019P000631       0
# 1014223  1014224  332670919P000083       0
# 1014224  1014225  106050119Y000587       0
#
# [1014225 rows x 3 columns]

# %%
data_fix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1014225 entries, 0 to 1014224
# Data columns (total 3 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0           1014225 non-null  string
#  1   FKP02   1014225 non-null  string
#  2   Status  1014225 non-null  int64
# dtypes: int64(1), string(2)
# memory usage: 23.2 MB

# %%
import csv
data_fix.to_csv('/content/gdrive/My Drive/BDC/submission12.csv',sep=',',quoting=csv.QUOTE_NONNUMERIC,index=False)
